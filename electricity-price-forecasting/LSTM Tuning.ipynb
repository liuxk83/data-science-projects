# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import itertools
import random
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Input, LSTM, Dense, Dropout
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error

# %%
root_path = Path("/Users/adminnistrator/Documents/Stanford/STATS 207/STATS-207-Final-Project")

# %%
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)

# %%
electricity_data = pd.read_csv(root_path / "clean_data.csv")

# Aggregate the data: compute the monthly average electricity price at the national level
electricity_data['date'] = pd.to_datetime(
    electricity_data[['year', 'month']].assign(day=1)
)  # Create a date column for time series analysis

# Calculate the monthly average price
national_avg_price = electricity_data.groupby('date')['price'].mean().reset_index()

national_avg_price.to_csv(root_path / "national_avg_price.csv", index = False)

# %%
national_avg_price['date'] = pd.to_datetime(national_avg_price['date'])
national_avg_price.set_index('date', inplace=True)
national_avg_price.head()
# Out:
#                price
# date
# 2001-01-01  7.136839
# 2001-02-01  7.271097
# 2001-03-01  7.443806
# 2001-04-01  7.544065
# 2001-05-01  7.675194

# %%
def create_lagged_features(data, lag=1):
    """
    Create lagged features for supervised learning.
    :param data: Input time series (numpy array or pandas Series).
    :param lag: Number of lagged observations to include.
    :return: Feature matrix X and target vector y.
    """
    X, y = [], []
    for i in range(len(data) - lag):
        X.append(data[i:i + lag])
        y.append(data[i + lag])
    return np.array(X), np.array(y)

# Function to create and compile LSTM model
def create_lstm_model(input_shape):
    # Use the Input layer to specify the input shape
    inputs = Input(shape=input_shape)
    x = LSTM(50, activation='relu')(inputs)  # Add LSTM layer after Input
    outputs = Dense(1)(x)  # Output layer
    model = Model(inputs=inputs, outputs=outputs)  # Create the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Function to create and compile the LSTM model
def create_tuned_lstm_model(input_shape, units, dropout_rate, learning_rate):
    model = Sequential([
        Input(shape=input_shape),  # Define input shape explicitly
        LSTM(units, return_sequences=False),  # LSTM layer
        Dropout(dropout_rate),  # Dropout for regularization
        Dense(1)  # Output layer for regression
    ])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse')
    return model

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data_normalized = scaler.fit_transform(national_avg_price)

# Create lagged features with a window size of 12
lag = 12
X, y = create_lagged_features(data_normalized, lag)

# Reshape X for LSTM (samples, timesteps, features)
X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
param_grid = {
    'units': [16, 32, 64],                # Number of LSTM units
    'dropout_rate': [0.1, 0.2, 0.3],      # Dropout rate
    'learning_rate': [0.001, 0.01],       # Learning rate
    'batch_size': [16, 32],               # Batch size
    'epochs': [30, 50]                    # Number of epochs
}

# Grid search for hyperparameter tuning
best_rmse = float('inf')
best_params = {}
results = []

# For plotting purposes
tscv = TimeSeriesSplit(n_splits=5)
all_rmse = []

param_combinations = itertools.product(
    param_grid['units'],
    param_grid['dropout_rate'],
    param_grid['learning_rate'],
    param_grid['batch_size'],
    param_grid['epochs']
)

for units, dropout_rate, learning_rate, batch_size, epochs in param_combinations:
    rmse_values = []
    print(f"Testing configuration: units={units}, dropout_rate={dropout_rate}, learning_rate={learning_rate}, batch_size={batch_size}, epochs={epochs}")

    for train_index, test_index in tscv.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        # Create the LSTM model with the current parameters
        model = create_tuned_lstm_model(
            input_shape=(X_train.shape[1], X_train.shape[2]),
            units=units,
            dropout_rate=dropout_rate,
            learning_rate=learning_rate
        )

        # Train the model
        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

        # Evaluate the model
        y_pred = model.predict(X_test)

        # Reshape X_test for denormalization (from 3D to 2D)
        X_test_reshaped = X_test.reshape(X_test.shape[0], -1)

        # Denormalize predictions and actual values
        y_pred_denormalized = scaler.inverse_transform(np.concatenate((X_test_reshaped, y_pred), axis=1))[:, -1]
        X_test_reshaped_actual = np.concatenate((X_test_reshaped, y_test.reshape(-1, 1)), axis=1)
        y_test_denormalized = scaler.inverse_transform(X_test_reshaped_actual)[:, -1]

        # Calculate RMSE using denormalized values
        rmse = np.sqrt(mean_squared_error(y_test_denormalized, y_pred_denormalized))
        rmse_values.append(rmse)

    # Average RMSE across folds
    avg_rmse = np.mean(rmse_values)
    all_rmse.append((avg_rmse, units, dropout_rate, learning_rate, batch_size, epochs))
    print(f"Average RMSE (denormalized): {avg_rmse:.4f}")

    # Save the best configuration
    if avg_rmse < best_rmse:
        best_rmse = avg_rmse
        best_params = {
            'units': units,
            'dropout_rate': dropout_rate,
            'learning_rate': learning_rate,
            'batch_size': batch_size,
            'epochs': epochs
        }
# Out:
# Testing configuration: units=16, dropout_rate=0.1, learning_rate=0.001, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.5097
# Testing configuration: units=16, dropout_rate=0.1, learning_rate=0.001, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Average RMSE (denormalized): 0.4767
# Testing configuration: units=16, dropout_rate=0.1, learning_rate=0.001, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Average RMSE (denormalized): 0.4124
# Testing configuration: units=16, dropout_rate=0.1, learning_rate=0.001, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Average RMSE (denormalized): 0.4476
# Testing configuration: units=16, dropout_rate=0.1, learning_rate=0.01, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Average RMSE (denormalized): 0.2803
# Testing configuration: units=16, dropout_rate=0.1, learning_rate=0.01, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Average RMSE (denormalized): 0.2411
# Testing configuration: units=16, dropout_rate=0.1, learning_rate=0.01, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Average RMSE (denormalized): 0.3525
# Testing configuration: units=16, dropout_rate=0.1, learning_rate=0.01, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Average RMSE (denormalized): 0.2955
# Testing configuration: units=16, dropout_rate=0.2, learning_rate=0.001, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Average RMSE (denormalized): 0.5516
# Testing configuration: units=16, dropout_rate=0.2, learning_rate=0.001, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Average RMSE (denormalized): 0.4180
# Testing configuration: units=16, dropout_rate=0.2, learning_rate=0.001, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Average RMSE (denormalized): 0.4706
# Testing configuration: units=16, dropout_rate=0.2, learning_rate=0.001, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Average RMSE (denormalized): 0.5296
# Testing configuration: units=16, dropout_rate=0.2, learning_rate=0.01, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Average RMSE (denormalized): 0.3458
# Testing configuration: units=16, dropout_rate=0.2, learning_rate=0.01, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Average RMSE (denormalized): 0.2557
# Testing configuration: units=16, dropout_rate=0.2, learning_rate=0.01, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Average RMSE (denormalized): 0.4107
# Testing configuration: units=16, dropout_rate=0.2, learning_rate=0.01, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Average RMSE (denormalized): 0.3328
# Testing configuration: units=16, dropout_rate=0.3, learning_rate=0.001, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Average RMSE (denormalized): 0.5101
# Testing configuration: units=16, dropout_rate=0.3, learning_rate=0.001, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Average RMSE (denormalized): 0.4367
# Testing configuration: units=16, dropout_rate=0.3, learning_rate=0.001, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Average RMSE (denormalized): 0.6074
# Testing configuration: units=16, dropout_rate=0.3, learning_rate=0.001, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Average RMSE (denormalized): 0.4448
# Testing configuration: units=16, dropout_rate=0.3, learning_rate=0.01, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.4323
# Testing configuration: units=16, dropout_rate=0.3, learning_rate=0.01, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Average RMSE (denormalized): 0.3394
# Testing configuration: units=16, dropout_rate=0.3, learning_rate=0.01, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.4031
# Testing configuration: units=16, dropout_rate=0.3, learning_rate=0.01, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Average RMSE (denormalized): 0.3419
# Testing configuration: units=32, dropout_rate=0.1, learning_rate=0.001, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Average RMSE (denormalized): 0.3980
# Testing configuration: units=32, dropout_rate=0.1, learning_rate=0.001, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.4618
# Testing configuration: units=32, dropout_rate=0.1, learning_rate=0.001, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Average RMSE (denormalized): 0.4798
# Testing configuration: units=32, dropout_rate=0.1, learning_rate=0.001, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Average RMSE (denormalized): 0.3950
# Testing configuration: units=32, dropout_rate=0.1, learning_rate=0.01, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Average RMSE (denormalized): 0.2386
# Testing configuration: units=32, dropout_rate=0.1, learning_rate=0.01, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Average RMSE (denormalized): 0.2037
# Testing configuration: units=32, dropout_rate=0.1, learning_rate=0.01, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Average RMSE (denormalized): 0.3022
# Testing configuration: units=32, dropout_rate=0.1, learning_rate=0.01, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Average RMSE (denormalized): 0.2796
# Testing configuration: units=32, dropout_rate=0.2, learning_rate=0.001, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Average RMSE (denormalized): 0.4234
# Testing configuration: units=32, dropout_rate=0.2, learning_rate=0.001, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Average RMSE (denormalized): 0.4283
# Testing configuration: units=32, dropout_rate=0.2, learning_rate=0.001, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Average RMSE (denormalized): 0.4442
# Testing configuration: units=32, dropout_rate=0.2, learning_rate=0.001, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.4470
# Testing configuration: units=32, dropout_rate=0.2, learning_rate=0.01, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Average RMSE (denormalized): 0.3150
# Testing configuration: units=32, dropout_rate=0.2, learning_rate=0.01, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Average RMSE (denormalized): 0.2491
# Testing configuration: units=32, dropout_rate=0.2, learning_rate=0.01, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Average RMSE (denormalized): 0.3328
# Testing configuration: units=32, dropout_rate=0.2, learning_rate=0.01, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Average RMSE (denormalized): 0.3306
# Testing configuration: units=32, dropout_rate=0.3, learning_rate=0.001, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Average RMSE (denormalized): 0.5286
# Testing configuration: units=32, dropout_rate=0.3, learning_rate=0.001, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Average RMSE (denormalized): 0.4344
# Testing configuration: units=32, dropout_rate=0.3, learning_rate=0.001, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.4079
# Testing configuration: units=32, dropout_rate=0.3, learning_rate=0.001, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.4914
# Testing configuration: units=32, dropout_rate=0.3, learning_rate=0.01, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Average RMSE (denormalized): 0.3187
# Testing configuration: units=32, dropout_rate=0.3, learning_rate=0.01, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.3021
# Testing configuration: units=32, dropout_rate=0.3, learning_rate=0.01, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Average RMSE (denormalized): 0.3716
# Testing configuration: units=32, dropout_rate=0.3, learning_rate=0.01, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Average RMSE (denormalized): 0.2867
# Testing configuration: units=64, dropout_rate=0.1, learning_rate=0.001, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Average RMSE (denormalized): 0.4349
# Testing configuration: units=64, dropout_rate=0.1, learning_rate=0.001, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Average RMSE (denormalized): 0.3937
# Testing configuration: units=64, dropout_rate=0.1, learning_rate=0.001, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.4621
# Testing configuration: units=64, dropout_rate=0.1, learning_rate=0.001, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.4013
# Testing configuration: units=64, dropout_rate=0.1, learning_rate=0.01, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Average RMSE (denormalized): 0.2321
# Testing configuration: units=64, dropout_rate=0.1, learning_rate=0.01, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Average RMSE (denormalized): 0.2016
# Testing configuration: units=64, dropout_rate=0.1, learning_rate=0.01, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Average RMSE (denormalized): 0.2734
# Testing configuration: units=64, dropout_rate=0.1, learning_rate=0.01, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.2456
# Testing configuration: units=64, dropout_rate=0.2, learning_rate=0.001, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Average RMSE (denormalized): 0.4105
# Testing configuration: units=64, dropout_rate=0.2, learning_rate=0.001, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Average RMSE (denormalized): 0.3882
# Testing configuration: units=64, dropout_rate=0.2, learning_rate=0.001, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Average RMSE (denormalized): 0.4712
# Testing configuration: units=64, dropout_rate=0.2, learning_rate=0.001, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Average RMSE (denormalized): 0.4350
# Testing configuration: units=64, dropout_rate=0.2, learning_rate=0.01, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.2179
# Testing configuration: units=64, dropout_rate=0.2, learning_rate=0.01, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.2508
# Testing configuration: units=64, dropout_rate=0.2, learning_rate=0.01, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.2818
# Testing configuration: units=64, dropout_rate=0.2, learning_rate=0.01, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.2211
# Testing configuration: units=64, dropout_rate=0.3, learning_rate=0.001, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.4258
# Testing configuration: units=64, dropout_rate=0.3, learning_rate=0.001, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Average RMSE (denormalized): 0.4340
# Testing configuration: units=64, dropout_rate=0.3, learning_rate=0.001, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Average RMSE (denormalized): 0.4602
# Testing configuration: units=64, dropout_rate=0.3, learning_rate=0.001, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Average RMSE (denormalized): 0.4102
# Testing configuration: units=64, dropout_rate=0.3, learning_rate=0.01, batch_size=16, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Average RMSE (denormalized): 0.3205
# Testing configuration: units=64, dropout_rate=0.3, learning_rate=0.01, batch_size=16, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Average RMSE (denormalized): 0.2487
# Testing configuration: units=64, dropout_rate=0.3, learning_rate=0.01, batch_size=32, epochs=30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Average RMSE (denormalized): 0.3246
# Testing configuration: units=64, dropout_rate=0.3, learning_rate=0.01, batch_size=32, epochs=50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Average RMSE (denormalized): 0.2551

# %%
# Print the best hyperparameters
print("\nBest Hyperparameters:")
print(best_params)
print(f"Best RMSE: {best_rmse:.4f}")
# Out:
# Best Hyperparameters:
# {'units': 64, 'dropout_rate': 0.1, 'learning_rate': 0.01, 'batch_size': 16, 'epochs': 50}
# Best RMSE: 0.2016

# %%
# Plot RMSE for different configurations
all_rmse_sorted = sorted(all_rmse, key=lambda x: x[0])
rmse_values_plot = [x[0] for x in all_rmse_sorted]

plt.figure(figsize=(10, 6))
plt.plot(range(len(rmse_values_plot)), rmse_values_plot, marker='o')
plt.title('RMSE for Different Hyperparameter Configurations')
plt.xlabel('Configuration Index')
plt.ylabel('RMSE')
plt.show()
